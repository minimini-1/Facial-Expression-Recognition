# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/iitp/Facial-Expression-Recognition/modeling
# Out:
# /content/drive/MyDrive/iitp/Facial-Expression-Recognition/modeling

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
from tqdm import tqdm
import re
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import random
import keras
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import IPython.display as display
plt.rc('font', family='NanumGothic')

# %%
@tf.function
def landmark_tfrecord_reader(example):
    feature_description = {"image": tf.io.VarLenFeature(dtype=tf.string),
                           "class": tf.io.VarLenFeature(dtype=tf.int64),
                           "landmark_points": tf.io.VarLenFeature(dtype=tf.float32)}

    inputs = {}
    example = tf.io.parse_single_example(example, feature_description)
    image_raw = tf.sparse.to_dense(example["image"])[0]
    inputs['image'] = tf.io.decode_png(image_raw, channels=3)
    image_class = tf.sparse.to_dense(example["class"])
    inputs['image_landmarks'] = tf.cast(tf.sparse.to_dense(example["landmark_points"]), tf.float32)
    return inputs, image_class

# %%
def image_scaling(x, y):
    x['image'] = tf.cast(x['image'], tf.float32) / 255.
    # x 480pixel, y 640pixel
    x['image_landmarks'] = tf.cast(x['image_landmarks'], tf.float32) / 640.
    return x, y

# %%
filenames = '../data/face_data_multi.tfrecord'
ds = tf.data.TFRecordDataset(filenames).map(landmark_tfrecord_reader)
ds = ds.map(image_scaling).batch(32)
ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
# dataset = tf.data.TFRecordDataset(filenames = ['../data/face_data4.tfrecord'])
# raw_example = next(iter(dataset))
# parsed = tf.train.Example.FromString(raw_example.numpy())

# parsed.features.feature['class']

# %%
# li = [] 
# for i in ds:    
#   for j in i[0]['image_landmarks']:    
#     if np.nan in j:
#       print("t")
#     # print(i[1].shape)

# %%
ds_size = len(list(ds))
ds_size
# Out:
# 15

# %%
train_size = int(0.7 * ds_size)
val_size = int(0.15 * ds_size)
test_size = int(0.15 * ds_size)

train_ds = ds.take(train_size)
test_ds = ds.skip(train_size)
val_ds = test_ds.skip(val_size)
test_ds = test_ds.take(test_size)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"./Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  # early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  # callbacks = [early_stopping, checkpoint]
  callbacks = [checkpoint]
  return callbacks

# %% [markdown]
# # with mobilenetV2

# %% [markdown]
# ### 새롭게 모델 다운

# %%
# # sequential 클래스 이용
# model2 = keras.models.Sequential()

# model2.add(keras.layers.Input(shape=(224,224,3)))
# model2.add(tf.keras.applications.mobilenet_v2.MobileNetV2(
#     input_shape=(224,224,3), alpha=1.0, include_top=False, weights='imagenet'
# ))
# model2.add(keras.layers.Flatten())

# model2.add(keras.layers.Dense(128))
# model2.add(keras.layers.BatchNormalization())
# model2.add(keras.layers.Activation('relu'))
# model2.add(keras.layers.Dropout(0.6))

# model2.add(keras.layers.Dense(64))

# # model2.add(keras.layers.Dense(1, activation='softmax'))
# model2.add(keras.layers.Dense(1, activation='sigmoid'))
# model2.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
#     loss='binary_crossentropy',
#     metrics=['accuracy'])

# %%
moblienet = tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(224,224,3), alpha=1.0, include_top=False, weights='imagenet'
)

# %%
# 함수형 api
input = keras.layers.Input(shape=(224,224,3), name='image')
x_image = moblienet(input)
x_image = keras.layers.GlobalMaxPooling2D()(x_image)
# x_image = keras.layers.Flatten()(x_image)
x_image = keras.layers.Dense(256)(x_image)
x_image = keras.layers.Dense(128)(x_image)

input2 = keras.layers.Input(shape=(266,), name='image_landmarks')
x_landmarks = keras.layers.Flatten()(input2)
x_landmark = keras.layers.Dense(128, input_dim=266)(x_landmarks)
x_landmark = keras.layers.BatchNormalization()(x_landmark)
x_landmark = keras.layers.Activation('relu')(x_landmark)
x = keras.layers.concatenate([x_image, x_landmark], axis=-1)

x = keras.layers.Dense(64)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(128)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.5)(x)

x = keras.layers.Dense(64)(x)
# output = keras.layers.Dense(1, activation='sigmoid')(x)
output = keras.layers.Dense(7, activation='softmax')(x)

model2 = keras.models.Model([input, input2], output)
model2.compile(
    optimizer=tf.keras.optimizers.Adagrad(),
    loss='categorical_crossentropy',
    metrics=['accuracy'])

# %% [markdown]
# ### 기존 모델로 계속 학습

# %%
model2 = tf.keras.models.load_model('Checkpoints/moblienetV2_4.h5')

# %% [markdown]
# ### 모델 학습

# %%
from keras.utils.vis_utils import plot_model
plot_model(model2)
# plot_model(model2, to_file='model.png')

# %%
model2.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  image_landmarks (InputLayer)   [(None, 266)]        0           []
#
#  mobilenetv2_1.00_224 (Function  (None, 7, 7, 1280)  2257984     ['image[0][0]']
#  al)
#
#  flatten_5 (Flatten)            (None, 266)          0           ['image_landmarks[0][0]']
#
#  global_max_pooling2d_5 (Global  (None, 1280)        0           ['mobilenetv2_1.00_224[0][0]']
#  MaxPooling2D)
#
#  dense_37 (Dense)               (None, 128)          34176       ['flatten_5[0][0]']
#
#  dense_35 (Dense)               (None, 256)          327936      ['global_max_pooling2d_5[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 128)         512         ['dense_37[0][0]']
#  ormalization)
#
#  dense_36 (Dense)               (None, 128)          32896       ['dense_35[0][0]']
#
#  activation_15 (Activation)     (None, 128)          0           ['batch_normalization_15[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 256)          0           ['dense_36[0][0]',
#                                                                   'activation_15[0][0]']
#
#  dense_38 (Dense)               (None, 64)           16448       ['concatenate_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64)          256         ['dense_38[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64)           0           ['batch_normalization_16[0][0]']
#
#  dropout_10 (Dropout)           (None, 64)           0           ['activation_16[0][0]']
#
#  dense_39 (Dense)               (None, 128)          8320        ['dropout_10[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 128)         512         ['dense_39[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 128)          0           ['batch_normalization_17[0][0]']
#
#  dropout_11 (Dropout)           (None, 128)          0           ['activation_17[0][0]']
#
#  dense_40 (Dense)               (None, 64)           8256        ['dropout_11[0][0]']
#
#  dense_41 (Dense)               (None, 7)            455         ['dense_40[0][0]']
#
# ==================================================================================================
# Total params: 2,687,751
# Trainable params: 2,652,999
# Non-trainable params: 34,752
# __________________________________________________________________________________________________

# %%
history2 = model2.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=callbackFunction('moblienetV2_landmark_multi_1'), batch_size=32)
# Out:
# Epoch 1/50
#      10/Unknown - 12s 197ms/step - loss: 1.8166 - accuracy: 0.3531
# Epoch 1: val_accuracy improved from -inf to 0.36765, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 15s 493ms/step - loss: 1.8166 - accuracy: 0.3531 - val_loss: 2.5425 - val_accuracy: 0.3676
# Epoch 2/50
# 10/10 [==============================] - ETA: 0s - loss: 0.8528 - accuracy: 0.7000
# Epoch 2: val_accuracy improved from 0.36765 to 0.38235, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 307ms/step - loss: 0.8528 - accuracy: 0.7000 - val_loss: 1.8929 - val_accuracy: 0.3824
# Epoch 3/50
# 10/10 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.8000
# Epoch 3: val_accuracy did not improve from 0.38235
# 10/10 [==============================] - 3s 278ms/step - loss: 0.6662 - accuracy: 0.8000 - val_loss: 1.6882 - val_accuracy: 0.3824
# Epoch 4/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.8469
# Epoch 4: val_accuracy did not improve from 0.38235
# 10/10 [==============================] - 2s 242ms/step - loss: 0.5940 - accuracy: 0.8469 - val_loss: 1.5569 - val_accuracy: 0.3824
# Epoch 5/50
# 10/10 [==============================] - ETA: 0s - loss: 0.5065 - accuracy: 0.8781
# Epoch 5: val_accuracy did not improve from 0.38235
# 10/10 [==============================] - 3s 275ms/step - loss: 0.5065 - accuracy: 0.8781 - val_loss: 1.4580 - val_accuracy: 0.3824
# Epoch 6/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4977 - accuracy: 0.8844
# Epoch 6: val_accuracy improved from 0.38235 to 0.41176, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 330ms/step - loss: 0.4977 - accuracy: 0.8844 - val_loss: 1.3949 - val_accuracy: 0.4118
# Epoch 7/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.8813
# Epoch 7: val_accuracy improved from 0.41176 to 0.45588, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 310ms/step - loss: 0.4590 - accuracy: 0.8813 - val_loss: 1.3448 - val_accuracy: 0.4559
# Epoch 8/50
# 10/10 [==============================] - ETA: 0s - loss: 0.4353 - accuracy: 0.8969
# Epoch 8: val_accuracy improved from 0.45588 to 0.47059, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 329ms/step - loss: 0.4353 - accuracy: 0.8969 - val_loss: 1.3052 - val_accuracy: 0.4706
# Epoch 9/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3515 - accuracy: 0.9438
# Epoch 9: val_accuracy improved from 0.47059 to 0.51471, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 308ms/step - loss: 0.3515 - accuracy: 0.9438 - val_loss: 1.2735 - val_accuracy: 0.5147
# Epoch 10/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.9312
# Epoch 10: val_accuracy improved from 0.51471 to 0.52941, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 304ms/step - loss: 0.3410 - accuracy: 0.9312 - val_loss: 1.2420 - val_accuracy: 0.5294
# Epoch 11/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3302 - accuracy: 0.9281
# Epoch 11: val_accuracy improved from 0.52941 to 0.54412, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 307ms/step - loss: 0.3302 - accuracy: 0.9281 - val_loss: 1.2435 - val_accuracy: 0.5441
# Epoch 12/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.9406
# Epoch 12: val_accuracy did not improve from 0.54412
# 10/10 [==============================] - 3s 273ms/step - loss: 0.3061 - accuracy: 0.9406 - val_loss: 1.2224 - val_accuracy: 0.5147
# Epoch 13/50
# 10/10 [==============================] - ETA: 0s - loss: 0.3201 - accuracy: 0.9375
# Epoch 13: val_accuracy did not improve from 0.54412
# 10/10 [==============================] - 3s 275ms/step - loss: 0.3201 - accuracy: 0.9375 - val_loss: 1.2209 - val_accuracy: 0.5147
# Epoch 14/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2651 - accuracy: 0.9625
# Epoch 14: val_accuracy did not improve from 0.54412
# 10/10 [==============================] - 2s 244ms/step - loss: 0.2651 - accuracy: 0.9625 - val_loss: 1.2193 - val_accuracy: 0.5441
# Epoch 15/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.9469
# Epoch 15: val_accuracy improved from 0.54412 to 0.55882, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 346ms/step - loss: 0.2788 - accuracy: 0.9469 - val_loss: 1.2125 - val_accuracy: 0.5588
# Epoch 16/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.9469
# Epoch 16: val_accuracy did not improve from 0.55882
# 10/10 [==============================] - 3s 276ms/step - loss: 0.2781 - accuracy: 0.9469 - val_loss: 1.2052 - val_accuracy: 0.5588
# Epoch 17/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.9625
# Epoch 17: val_accuracy did not improve from 0.55882
# 10/10 [==============================] - 3s 280ms/step - loss: 0.2489 - accuracy: 0.9625 - val_loss: 1.2030 - val_accuracy: 0.5441
# Epoch 18/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9594
# Epoch 18: val_accuracy improved from 0.55882 to 0.57353, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 4s 374ms/step - loss: 0.2540 - accuracy: 0.9594 - val_loss: 1.1863 - val_accuracy: 0.5735
# Epoch 19/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9688
# Epoch 19: val_accuracy did not improve from 0.57353
# 10/10 [==============================] - 3s 293ms/step - loss: 0.2232 - accuracy: 0.9688 - val_loss: 1.1733 - val_accuracy: 0.5735
# Epoch 20/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9594
# Epoch 20: val_accuracy did not improve from 0.57353
# 10/10 [==============================] - 2s 246ms/step - loss: 0.2248 - accuracy: 0.9594 - val_loss: 1.1559 - val_accuracy: 0.5735
# Epoch 21/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9688
# Epoch 21: val_accuracy did not improve from 0.57353
# 10/10 [==============================] - 2s 243ms/step - loss: 0.2089 - accuracy: 0.9688 - val_loss: 1.1405 - val_accuracy: 0.5588
# Epoch 22/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9688
# Epoch 22: val_accuracy did not improve from 0.57353
# 10/10 [==============================] - 2s 242ms/step - loss: 0.2085 - accuracy: 0.9688 - val_loss: 1.1303 - val_accuracy: 0.5735
# Epoch 23/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9688
# Epoch 23: val_accuracy did not improve from 0.57353
# 10/10 [==============================] - 2s 246ms/step - loss: 0.2043 - accuracy: 0.9688 - val_loss: 1.1113 - val_accuracy: 0.5735
# Epoch 24/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9781
# Epoch 24: val_accuracy improved from 0.57353 to 0.60294, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 346ms/step - loss: 0.1996 - accuracy: 0.9781 - val_loss: 1.1002 - val_accuracy: 0.6029
# Epoch 25/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9469
# Epoch 25: val_accuracy improved from 0.60294 to 0.61765, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 309ms/step - loss: 0.2185 - accuracy: 0.9469 - val_loss: 1.0938 - val_accuracy: 0.6176
# Epoch 26/50
# 10/10 [==============================] - ETA: 0s - loss: 0.2065 - accuracy: 0.9750
# Epoch 26: val_accuracy did not improve from 0.61765
# 10/10 [==============================] - 3s 246ms/step - loss: 0.2065 - accuracy: 0.9750 - val_loss: 1.0887 - val_accuracy: 0.6029
# Epoch 27/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9844
# Epoch 27: val_accuracy did not improve from 0.61765
# 10/10 [==============================] - 3s 284ms/step - loss: 0.1722 - accuracy: 0.9844 - val_loss: 1.0787 - val_accuracy: 0.5735
# Epoch 28/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9875
# Epoch 28: val_accuracy did not improve from 0.61765
# 10/10 [==============================] - 3s 281ms/step - loss: 0.1901 - accuracy: 0.9875 - val_loss: 1.0638 - val_accuracy: 0.6029
# Epoch 29/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9531
# Epoch 29: val_accuracy did not improve from 0.61765
# 10/10 [==============================] - 3s 247ms/step - loss: 0.1860 - accuracy: 0.9531 - val_loss: 1.0560 - val_accuracy: 0.6029
# Epoch 30/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9875
# Epoch 30: val_accuracy did not improve from 0.61765
# 10/10 [==============================] - 2s 244ms/step - loss: 0.1690 - accuracy: 0.9875 - val_loss: 1.0534 - val_accuracy: 0.6029
# Epoch 31/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1865 - accuracy: 0.9844
# Epoch 31: val_accuracy did not improve from 0.61765
# 10/10 [==============================] - 2s 244ms/step - loss: 0.1865 - accuracy: 0.9844 - val_loss: 1.0318 - val_accuracy: 0.6176
# Epoch 32/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9812
# Epoch 32: val_accuracy improved from 0.61765 to 0.66176, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 355ms/step - loss: 0.1611 - accuracy: 0.9812 - val_loss: 1.0271 - val_accuracy: 0.6618
# Epoch 33/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9875
# Epoch 33: val_accuracy did not improve from 0.66176
# 10/10 [==============================] - 3s 250ms/step - loss: 0.1750 - accuracy: 0.9875 - val_loss: 1.0217 - val_accuracy: 0.6618
# Epoch 34/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9906
# Epoch 34: val_accuracy improved from 0.66176 to 0.67647, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 342ms/step - loss: 0.1375 - accuracy: 0.9906 - val_loss: 1.0091 - val_accuracy: 0.6765
# Epoch 35/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.9781
# Epoch 35: val_accuracy did not improve from 0.67647
# 10/10 [==============================] - 3s 313ms/step - loss: 0.1498 - accuracy: 0.9781 - val_loss: 0.9957 - val_accuracy: 0.6765
# Epoch 36/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9844
# Epoch 36: val_accuracy did not improve from 0.67647
# 10/10 [==============================] - 3s 277ms/step - loss: 0.1484 - accuracy: 0.9844 - val_loss: 0.9880 - val_accuracy: 0.6765
# Epoch 37/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9781
# Epoch 37: val_accuracy improved from 0.67647 to 0.70588, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1366 - accuracy: 0.9781 - val_loss: 0.9764 - val_accuracy: 0.7059
# Epoch 38/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9844
# Epoch 38: val_accuracy did not improve from 0.70588
# 10/10 [==============================] - 3s 282ms/step - loss: 0.1465 - accuracy: 0.9844 - val_loss: 0.9723 - val_accuracy: 0.7059
# Epoch 39/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9906
# Epoch 39: val_accuracy improved from 0.70588 to 0.73529, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 315ms/step - loss: 0.1290 - accuracy: 0.9906 - val_loss: 0.9569 - val_accuracy: 0.7353
# Epoch 40/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9844
# Epoch 40: val_accuracy improved from 0.73529 to 0.75000, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 347ms/step - loss: 0.1412 - accuracy: 0.9844 - val_loss: 0.9382 - val_accuracy: 0.7500
# Epoch 41/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9812
# Epoch 41: val_accuracy did not improve from 0.75000
# 10/10 [==============================] - 3s 282ms/step - loss: 0.1333 - accuracy: 0.9812 - val_loss: 0.9280 - val_accuracy: 0.7353
# Epoch 42/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9937
# Epoch 42: val_accuracy did not improve from 0.75000
# 10/10 [==============================] - 3s 282ms/step - loss: 0.1406 - accuracy: 0.9937 - val_loss: 0.9154 - val_accuracy: 0.7500
# Epoch 43/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9812
# Epoch 43: val_accuracy did not improve from 0.75000
# 10/10 [==============================] - 3s 280ms/step - loss: 0.1520 - accuracy: 0.9812 - val_loss: 0.9008 - val_accuracy: 0.7500
# Epoch 44/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9875
# Epoch 44: val_accuracy did not improve from 0.75000
# 10/10 [==============================] - 2s 248ms/step - loss: 0.1228 - accuracy: 0.9875 - val_loss: 0.8934 - val_accuracy: 0.7500
# Epoch 45/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9781
# Epoch 45: val_accuracy improved from 0.75000 to 0.77941, saving model to ./Checkpoints/moblienetV2_landmark_multi_1.h5
# 10/10 [==============================] - 3s 354ms/step - loss: 0.1556 - accuracy: 0.9781 - val_loss: 0.8787 - val_accuracy: 0.7794
# Epoch 46/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9812
# Epoch 46: val_accuracy did not improve from 0.77941
# 10/10 [==============================] - 2s 247ms/step - loss: 0.1406 - accuracy: 0.9812 - val_loss: 0.8603 - val_accuracy: 0.7794
# Epoch 47/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9906
# Epoch 47: val_accuracy did not improve from 0.77941
# 10/10 [==============================] - 3s 283ms/step - loss: 0.1253 - accuracy: 0.9906 - val_loss: 0.8545 - val_accuracy: 0.7794
# Epoch 48/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9937
# Epoch 48: val_accuracy did not improve from 0.77941
# 10/10 [==============================] - 3s 281ms/step - loss: 0.1102 - accuracy: 0.9937 - val_loss: 0.8424 - val_accuracy: 0.7794
# Epoch 49/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9906
# Epoch 49: val_accuracy did not improve from 0.77941
# 10/10 [==============================] - 3s 285ms/step - loss: 0.1052 - accuracy: 0.9906 - val_loss: 0.8220 - val_accuracy: 0.7794
# Epoch 50/50
# 10/10 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9875
# Epoch 50: val_accuracy did not improve from 0.77941
# 10/10 [==============================] - 2s 246ms/step - loss: 0.1163 - accuracy: 0.9875 - val_loss: 0.8188 - val_accuracy: 0.7794

# %%
loss = history2.history['loss']
loss_val = history2.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='loss_val')
plt.title('value of the loss function')
plt.xlabel('epochs')
plt.ylabel('value of the loss function')
plt.legend()
plt.grid()
plt.show()

# %%
train_loss, train_acc = model2.evaluate(train_ds)
print('Train Accuracy:', train_acc*100)
print('\n')

test_loss, test_acc = model2.evaluate(test_ds)
print('Test Accuracy:', test_acc*100)
print('\n')

val_loss, val_acc = model2.evaluate(val_ds)
print('Validation Accuracy:', val_acc*100)
# Out:
# 10/10 [==============================] - 1s 72ms/step - loss: 0.7113 - accuracy: 0.8813
# Train Accuracy: 88.12500238418579
#
#
# 2/2 [==============================] - 1s 121ms/step - loss: 0.7414 - accuracy: 0.9062
# Test Accuracy: 90.625
#
#
# 3/3 [==============================] - 1s 46ms/step - loss: 0.7002 - accuracy: 0.8676
# Validation Accuracy: 86.76470518112183

# %% [markdown]
# ### 결과 확인하기

# %%
filenames = '../data/face_data2.tfrecord'
new_test = tf.data.TFRecordDataset(filenames).map(landmark_tfrecord_reader)
new_test = new_test.map(image_scaling).batch(16)
new_test = new_test.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
for i in new_test.take(1):
    sample = i
sample_input ={}
sample_input['image_landmarks'] = sample[0]['image_landmarks']
sample_input['image'] = sample[0]['image']

cls = model2(sample_input)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')

# %%
label_pair = {0: '중립', 1: '눈썹들어올리기', 2: '두눈감기', 3: '두눈크게뜨기', 4: '미소짓기',
              5: '입벌리기', 6: '입술오므리기'}
for i in test_ds.take(1):
    sample = i
sample_input ={}
sample_input['image_landmarks'] = sample[0]['image_landmarks']
sample_input['image'] = sample[0]['image']

cls = model2(sample_input)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample_input['image'][i].numpy()
    labels = list(cls[i].numpy())
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(label_pair[np.argmax(labels)]) 
    plt.imshow(image)
    plt.axis('off')

# %%
num = 25
raw_example = next(iter(test_ds))
image = raw_example[0]['image'][num].numpy()
cls = model2(raw_example[0])
labels = cls[num].numpy()
ax = plt.subplot(3, 3, i + 1)
ax.set_title(labels) 
plt.imshow(image)
plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# # moblienetV2 structure

# %%
model1 = keras.models.Sequential()

model1.add(keras.layers.Input(shape=(256,256,3)))
model1.add(tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(256,256,3), alpha=1.0, include_top=False
))
model1.add(keras.layers.Flatten())

model1.add(keras.layers.Dense(128))
model1.add(keras.layers.BatchNormalization())
model1.add(keras.layers.Activation('relu'))
model1.add(keras.layers.Dropout(0.25))

model1.add(keras.layers.Dense(64))

model1.add(keras.layers.Dense(1, activation='sigmoid'))
model1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 8, 8, 1280)       2257984
#  ional)
#
#  flatten_1 (Flatten)         (None, 81920)             0
#
#  dense_3 (Dense)             (None, 128)               10485888
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12,752,705
# Trainable params: 12,718,337
# Non-trainable params: 34,368
# _________________________________________________________________

# %%
history1 = model1.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=callbackFunction('moblienetV2_noweight'), batch_size=32)
# Out:
# Epoch 1/50
#       9/Unknown - 23s 134ms/step - loss: 0.0688 - accuracy: 0.9792
# Epoch 1: val_accuracy improved from -inf to 0.69767, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 28s 757ms/step - loss: 0.0688 - accuracy: 0.9792 - val_loss: 7.0072 - val_accuracy: 0.6977
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 2: val_accuracy did not improve from 0.69767
# 9/9 [==============================] - 2s 166ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.0622 - val_accuracy: 0.6977
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 3: val_accuracy improved from 0.69767 to 0.72093, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 4s 474ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3490 - val_accuracy: 0.7209
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 5.4341e-04 - accuracy: 1.0000
# Epoch 4: val_accuracy improved from 0.72093 to 0.83721, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 3s 306ms/step - loss: 5.4341e-04 - accuracy: 1.0000 - val_loss: 0.8140 - val_accuracy: 0.8372
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 3.3306e-04 - accuracy: 1.0000
# Epoch 5: val_accuracy improved from 0.83721 to 0.86047, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 3s 315ms/step - loss: 3.3306e-04 - accuracy: 1.0000 - val_loss: 0.6104 - val_accuracy: 0.8605
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 2.6536e-04 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 170ms/step - loss: 2.6536e-04 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 0.8605
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 1.9879e-04 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 180ms/step - loss: 1.9879e-04 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.8605
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 1.6248e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 173ms/step - loss: 1.6248e-04 - accuracy: 1.0000 - val_loss: 0.4413 - val_accuracy: 0.8605
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 2.2820e-04 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 179ms/step - loss: 2.2820e-04 - accuracy: 1.0000 - val_loss: 0.4115 - val_accuracy: 0.8605
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 1.3013e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 172ms/step - loss: 1.3013e-04 - accuracy: 1.0000 - val_loss: 0.3952 - val_accuracy: 0.8605
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 1.4562e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 169ms/step - loss: 1.4562e-04 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.8605
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2822e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 171ms/step - loss: 1.2822e-04 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.8605
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2351e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 184ms/step - loss: 1.2351e-04 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8605
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 1.0848e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 169ms/step - loss: 1.0848e-04 - accuracy: 1.0000 - val_loss: 0.3886 - val_accuracy: 0.8605
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 9.5846e-05 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 173ms/step - loss: 9.5846e-05 - accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.8605
# Epoch 15: early stopping

# %%
loss = history1.history['loss']
loss_val = history1.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='loss_val')
plt.title('value of the loss function')
plt.xlabel('epochs')
plt.ylabel('value of the loss function')
plt.legend()
plt.grid()
plt.show()

# %%
train_loss, train_acc = model1.evaluate(train_ds)
print('Train Accuracy:', train_acc*100)
print('\n')

test_loss, test_acc = model1.evaluate(test_ds)
print('Test Accuracy:', test_acc*100)
print('\n')

val_loss, val_acc = model1.evaluate(val_ds)
print('Validation Accuracy:', val_acc*100)
# Out:
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5436 - accuracy: 0.7917
# Train Accuracy: 79.16666865348816
#
#
# 1/1 [==============================] - 0s 264ms/step - loss: 0.6207 - accuracy: 0.7500
# Test Accuracy: 75.0
#
#
# 3/3 [==============================] - 1s 62ms/step - loss: 0.3811 - accuracy: 0.8605
# Validation Accuracy: 86.04651093482971

# %% [markdown]
# ## 결과 확인하기

# %%
for i in test_ds.take(1):
    sample = i
sample = sample[0]
cls = model1(sample)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
