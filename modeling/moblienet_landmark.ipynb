# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/iitp/Facial-Expression-Recognition/modeling
# Out:
# /content/drive/MyDrive/iitp/Facial-Expression-Recognition/modeling

# %%
from tqdm import tqdm
import re
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import random
import keras
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import IPython.display as display

# %%
@tf.function
def landmark_tfrecord_reader(example):
    feature_description = {"image": tf.io.VarLenFeature(dtype=tf.string),
                           "class": tf.io.VarLenFeature(dtype=tf.int64),
                           "landmark_points": tf.io.VarLenFeature(dtype=tf.float32)}

    inputs = {}
    example = tf.io.parse_single_example(example, feature_description)
    image_raw = tf.sparse.to_dense(example["image"])[0]
    inputs['image'] = tf.io.decode_png(image_raw, channels=3)
    image_class = tf.sparse.to_dense(example["class"])
    inputs['image_landmarks'] = tf.sparse.to_dense(example["landmark_points"])
    return inputs, image_class

# %%
def image_scaling(x, y):
    x['image'] = tf.cast(x['image'], tf.float32) / 255.
    return x, y

# %%
filenames = '../data/face_data7.tfrecord'
ds = tf.data.TFRecordDataset(filenames).map(landmark_tfrecord_reader)
ds = ds.map(image_scaling).batch(16)
ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
for i in ds.take(1):
    print(i[0]['image'].shape)
    print(i[1].shape)
# Out:
# (16, 224, 224, 3)
# (16, 1)

# %%
ds_size = len(list(ds))
ds_size
# Out:
# 65

# %%
train_size = int(0.7 * ds_size)
val_size = int(0.15 * ds_size)
test_size = int(0.15 * ds_size)

train_ds = ds.take(train_size)
test_ds = ds.skip(train_size)
val_ds = test_ds.skip(val_size)
test_ds = test_ds.take(test_size)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"./Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  # early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  # callbacks = [early_stopping, checkpoint]
  callbacks = [checkpoint]
  return callbacks

# %% [markdown]
# # with mobilenetV3

# %% [markdown]
# ### 새롭게 모델 다운

# %%
moblienet =tf.keras.applications.MobileNet(
    input_shape=(224,224,3), alpha=1.0, include_top=False, weights='imagenet'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jongm\Desktop\MINI\projects\Facial-Expression-Recognition\modeling\moblienet_landmark.ipynb 셀 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/projects/Facial-Expression-Recognition/modeling/moblienet_landmark.ipynb#ch0000012?line=0'>1</a> moblienet =tf.keras.applications.MobileNet(
#       <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/projects/Facial-Expression-Recognition/modeling/moblienet_landmark.ipynb#ch0000012?line=1'>2</a>     input_shape=(224,224,3), alpha=1.0, include_top=False, weights='imagenet'
#       <a href='vscode-notebook-cell:/c%3A/Users/jongm/Desktop/MINI/projects/Facial-Expression-Recognition/modeling/moblienet_landmark.ipynb#ch0000012?line=2'>3</a> )
#
# NameError: name 'tf' is not defined

# %%
for layer in moblienet.layers:
    layer.trainable = True

# %%
# 함수형 api
input = keras.layers.Input(shape=(224,224,3), name='image')
input2 = keras.layers.Input(shape=(266), name='image_landmarks')
x = moblienet(input)
x = keras.layers.Flatten()(x)

x2 = keras.layers.Dense(128)(input2)
x2 = keras.layers.BatchNormalization()(x2)
x2 = keras.layers.Activation('relu')(x2)
x = keras.layers.concatenate([x, x2])

x = keras.layers.Dense(256)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(128)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.7)(x)

x = keras.layers.Dense(64)(x)
output = keras.layers.Dense(1, activation='sigmoid')(x)
# x_class = keras.layers.Dense(1, activation='sigmoid')(x)
# x_landmark = keras.layers.Dense(266)(x)
# output = keras.layers.concatenate([x_class, x_landmark])

model2 = keras.models.Model(inputs=[input, input2], outputs=output)
model2.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    # optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=['accuracy'])

# %% [markdown]
# ### 기존 모델로 계속 학습

# %%
model2 = tf.keras.models.load_model('Checkpoints/moblienetV2_4.h5')

# %% [markdown]
# ### 모델 학습

# %%
from keras.utils.vis_utils import plot_model
plot_model(model2, to_file='model.png')

# %%
model2.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_landmarks (InputLayer)   [(None, 266)]        0           []
#
#  image (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  dense_26 (Dense)               (None, 128)          34176       ['image_landmarks[0][0]']
#
#  MobilenetV3large (Functional)  (None, 7, 7, 960)    2996352     ['image[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 128)         512         ['dense_26[0][0]']
#  ormalization)
#
#  flatten_3 (Flatten)            (None, 47040)        0           ['MobilenetV3large[1][0]']
#
#  activation_16 (Activation)     (None, 128)          0           ['batch_normalization_16[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 47168)        0           ['flatten_3[0][0]',
#                                                                   'activation_16[0][0]']
#
#  dense_27 (Dense)               (None, 256)          12075264    ['concatenate_6[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 256)         1024        ['dense_27[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 256)          0           ['batch_normalization_17[0][0]']
#
#  dropout_10 (Dropout)           (None, 256)          0           ['activation_17[0][0]']
#
#  dense_28 (Dense)               (None, 128)          32896       ['dropout_10[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 128)         512         ['dense_28[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 128)          0           ['batch_normalization_18[0][0]']
#
#  dropout_11 (Dropout)           (None, 128)          0           ['activation_18[0][0]']
#
#  dense_29 (Dense)               (None, 64)           8256        ['dropout_11[0][0]']
#
#  dense_30 (Dense)               (None, 1)            65          ['dense_29[0][0]']
#
# ==================================================================================================
# Total params: 15,149,057
# Trainable params: 15,123,633
# Non-trainable params: 25,424
# __________________________________________________________________________________________________

# %%
history2 = model2.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=callbackFunction('moblienetV3_landmark_1'), batch_size=8)
# Out:
# Epoch 1/50
#      11/Unknown - 15s 1s/step - loss: 0.4584 - accuracy: 0.7898
# Epoch 1: val_accuracy improved from -inf to 0.38636, saving model to ./Checkpoints\moblienetV3_landmark_1.h5
# 11/11 [==============================] - 17s 1s/step - loss: 0.4584 - accuracy: 0.7898 - val_loss: 2.4913 - val_accuracy: 0.3864
# Epoch 2/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9773
# Epoch 2: val_accuracy improved from 0.38636 to 0.93182, saving model to ./Checkpoints\moblienetV3_landmark_1.h5
# 11/11 [==============================] - 15s 1s/step - loss: 0.0972 - accuracy: 0.9773 - val_loss: 0.2193 - val_accuracy: 0.9318
# Epoch 3/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9886
# Epoch 3: val_accuracy improved from 0.93182 to 1.00000, saving model to ./Checkpoints\moblienetV3_landmark_1.h5
# 11/11 [==============================] - 14s 1s/step - loss: 0.0295 - accuracy: 0.9886 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 4/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 5/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 6/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 7/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 8/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 6.0483e-04 - val_accuracy: 1.0000
# Epoch 9/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.5986e-04 - val_accuracy: 1.0000
# Epoch 10/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.3822e-04 - val_accuracy: 1.0000
# Epoch 11/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.6625e-05 - val_accuracy: 1.0000
# Epoch 12/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 7.5987e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 6.0344e-05 - val_accuracy: 1.0000
# Epoch 14/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 4.5205e-05 - val_accuracy: 1.0000
# Epoch 15/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.5953e-05 - val_accuracy: 1.0000
# Epoch 16/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.0375e-05 - val_accuracy: 1.0000
# Epoch 17/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.7229e-05 - val_accuracy: 1.0000
# Epoch 18/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.5073e-05 - val_accuracy: 1.0000
# Epoch 19/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.3516e-05 - val_accuracy: 1.0000
# Epoch 20/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.0206e-05 - val_accuracy: 1.0000
# Epoch 21/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 16s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.8638e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 11/11 [==============================] - ETA: 0s - loss: 9.7938e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 9.7938e-04 - accuracy: 1.0000 - val_loss: 1.6532e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 11/11 [==============================] - ETA: 0s - loss: 7.7963e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 7.7963e-04 - accuracy: 1.0000 - val_loss: 1.4615e-05 - val_accuracy: 1.0000
# Epoch 24/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3773e-05 - val_accuracy: 1.0000
# Epoch 25/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2928e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2049e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0817e-05 - val_accuracy: 1.0000
# Epoch 28/50
# 11/11 [==============================] - ETA: 0s - loss: 4.8683e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 4.8683e-04 - accuracy: 1.0000 - val_loss: 1.0228e-05 - val_accuracy: 1.0000
# Epoch 29/50
# 11/11 [==============================] - ETA: 0s - loss: 4.7214e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 4.7214e-04 - accuracy: 1.0000 - val_loss: 1.0099e-05 - val_accuracy: 1.0000
# Epoch 30/50
# 11/11 [==============================] - ETA: 0s - loss: 4.8409e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 4.8409e-04 - accuracy: 1.0000 - val_loss: 1.0022e-05 - val_accuracy: 1.0000
# Epoch 31/50
# 11/11 [==============================] - ETA: 0s - loss: 9.0612e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 9.0612e-04 - accuracy: 1.0000 - val_loss: 9.9045e-06 - val_accuracy: 1.0000
# Epoch 32/50
# 11/11 [==============================] - ETA: 0s - loss: 5.6484e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 5.6484e-04 - accuracy: 1.0000 - val_loss: 9.6414e-06 - val_accuracy: 1.0000
# Epoch 33/50
# 11/11 [==============================] - ETA: 0s - loss: 3.3043e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 3.3043e-04 - accuracy: 1.0000 - val_loss: 9.4603e-06 - val_accuracy: 1.0000
# Epoch 34/50
# 11/11 [==============================] - ETA: 0s - loss: 7.6918e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 7.6918e-04 - accuracy: 1.0000 - val_loss: 8.8261e-06 - val_accuracy: 1.0000
# Epoch 35/50
# 11/11 [==============================] - ETA: 0s - loss: 3.4883e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 3.4883e-04 - accuracy: 1.0000 - val_loss: 8.3137e-06 - val_accuracy: 1.0000
# Epoch 36/50
# 11/11 [==============================] - ETA: 0s - loss: 7.4573e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 7.4573e-04 - accuracy: 1.0000 - val_loss: 8.2281e-06 - val_accuracy: 1.0000
# Epoch 37/50
# 11/11 [==============================] - ETA: 0s - loss: 4.5719e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 4.5719e-04 - accuracy: 1.0000 - val_loss: 8.6269e-06 - val_accuracy: 1.0000
# Epoch 38/50
# 11/11 [==============================] - ETA: 0s - loss: 6.2423e-04 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 16s 1s/step - loss: 6.2423e-04 - accuracy: 1.0000 - val_loss: 8.1878e-06 - val_accuracy: 1.0000
# Epoch 39/50
# 11/11 [==============================] - ETA: 0s - loss: 3.8313e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 3.8313e-04 - accuracy: 1.0000 - val_loss: 7.3834e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 11/11 [==============================] - ETA: 0s - loss: 4.4089e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 4.4089e-04 - accuracy: 1.0000 - val_loss: 6.7130e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 11/11 [==============================] - ETA: 0s - loss: 2.1182e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 16s 1s/step - loss: 2.1182e-04 - accuracy: 1.0000 - val_loss: 6.2472e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 11/11 [==============================] - ETA: 0s - loss: 6.0677e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 16s 1s/step - loss: 6.0677e-04 - accuracy: 1.0000 - val_loss: 6.2121e-06 - val_accuracy: 1.0000
# Epoch 43/50
# 11/11 [==============================] - ETA: 0s - loss: 3.4514e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 3.4514e-04 - accuracy: 1.0000 - val_loss: 6.0890e-06 - val_accuracy: 1.0000
# Epoch 44/50
# 11/11 [==============================] - ETA: 0s - loss: 2.8118e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 15s 1s/step - loss: 2.8118e-04 - accuracy: 1.0000 - val_loss: 5.9772e-06 - val_accuracy: 1.0000
# Epoch 45/50
# 11/11 [==============================] - ETA: 0s - loss: 2.6360e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 13s 1s/step - loss: 2.6360e-04 - accuracy: 1.0000 - val_loss: 5.6898e-06 - val_accuracy: 1.0000
# Epoch 46/50
# 11/11 [==============================] - ETA: 0s - loss: 4.2249e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 13s 1s/step - loss: 4.2249e-04 - accuracy: 1.0000 - val_loss: 5.5532e-06 - val_accuracy: 1.0000
# Epoch 47/50
# 11/11 [==============================] - ETA: 0s - loss: 3.6685e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 14s 1s/step - loss: 3.6685e-04 - accuracy: 1.0000 - val_loss: 5.3764e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 11/11 [==============================] - ETA: 0s - loss: 3.6486e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 13s 1s/step - loss: 3.6486e-04 - accuracy: 1.0000 - val_loss: 4.9696e-06 - val_accuracy: 1.0000
# Epoch 49/50
# 11/11 [==============================] - ETA: 0s - loss: 5.6003e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 13s 1s/step - loss: 5.6003e-04 - accuracy: 1.0000 - val_loss: 4.5085e-06 - val_accuracy: 1.0000
# Epoch 50/50
# 11/11 [==============================] - ETA: 0s - loss: 2.4487e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 13s 1s/step - loss: 2.4487e-04 - accuracy: 1.0000 - val_loss: 4.1177e-06 - val_accuracy: 1.0000

# %%
loss = history2.history['loss']
loss_val = history2.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='loss_val')
plt.title('value of the loss function')
plt.xlabel('epochs')
plt.ylabel('value of the loss function')
plt.legend()
plt.grid()
plt.show()

# %%
train_loss, train_acc = model2.evaluate(train_ds)
print('Train Accuracy:', train_acc*100)
print('\n')

test_loss, test_acc = model2.evaluate(test_ds)
print('Test Accuracy:', test_acc*100)
print('\n')

val_loss, val_acc = model2.evaluate(val_ds)
print('Validation Accuracy:', val_acc*100)
# Out:
# 11/11 [==============================] - 3s 272ms/step - loss: 3.7730e-06 - accuracy: 1.0000
# Train Accuracy: 100.0
#
#
# 2/2 [==============================] - 1s 351ms/step - loss: 4.4822e-06 - accuracy: 1.0000
# Test Accuracy: 100.0
#
#
# 3/3 [==============================] - 1s 300ms/step - loss: 4.1177e-06 - accuracy: 1.0000
# Validation Accuracy: 100.0

# %% [markdown]
# ### 결과 확인하기

# %%
filenames = '../data/face_data2.tfrecord'
new_test = tf.data.TFRecordDataset(filenames).map(landmark_tfrecord_reader)
new_test = new_test.map(image_scaling).batch(16)
new_test = new_test.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
for i in new_test.take(1):
    sample = i
sample_input ={}
sample_input['image_landmarks'] = sample[0]['image_landmarks']
sample_input['image'] = sample[0]['image']

cls = model2(sample_input)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')

# %%
for i in test_ds.take(1):
    sample = i
sample_input ={}
sample_input['image_landmarks'] = sample[0]['image_landmarks']
sample_input['image'] = sample[0]['image']

cls = model2(sample_input)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample_input['image'][i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')
# Out:
# c:\Users\jongm\Anaconda3\envs\tfcpu\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
raw_example = next(iter(test_ds))
image = raw_example[0]['image'][15].numpy()
cls = model2(raw_example[0])
labels = cls[15].numpy()
ax = plt.subplot(3, 3, i + 1)
ax.set_title(labels) 
plt.imshow(image)
plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# # moblienetV2 structure

# %%
model1 = keras.models.Sequential()

model1.add(keras.layers.Input(shape=(256,256,3)))
model1.add(tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(256,256,3), alpha=1.0, include_top=False
))
model1.add(keras.layers.Flatten())

model1.add(keras.layers.Dense(128))
model1.add(keras.layers.BatchNormalization())
model1.add(keras.layers.Activation('relu'))
model1.add(keras.layers.Dropout(0.25))

model1.add(keras.layers.Dense(64))

model1.add(keras.layers.Dense(1, activation='sigmoid'))
model1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 8, 8, 1280)       2257984
#  ional)
#
#  flatten_1 (Flatten)         (None, 81920)             0
#
#  dense_3 (Dense)             (None, 128)               10485888
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12,752,705
# Trainable params: 12,718,337
# Non-trainable params: 34,368
# _________________________________________________________________

# %%
history1 = model1.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=callbackFunction('moblienetV2_noweight'), batch_size=32)
# Out:
# Epoch 1/50
#       9/Unknown - 23s 134ms/step - loss: 0.0688 - accuracy: 0.9792
# Epoch 1: val_accuracy improved from -inf to 0.69767, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 28s 757ms/step - loss: 0.0688 - accuracy: 0.9792 - val_loss: 7.0072 - val_accuracy: 0.6977
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 2: val_accuracy did not improve from 0.69767
# 9/9 [==============================] - 2s 166ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.0622 - val_accuracy: 0.6977
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 3: val_accuracy improved from 0.69767 to 0.72093, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 4s 474ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3490 - val_accuracy: 0.7209
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 5.4341e-04 - accuracy: 1.0000
# Epoch 4: val_accuracy improved from 0.72093 to 0.83721, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 3s 306ms/step - loss: 5.4341e-04 - accuracy: 1.0000 - val_loss: 0.8140 - val_accuracy: 0.8372
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 3.3306e-04 - accuracy: 1.0000
# Epoch 5: val_accuracy improved from 0.83721 to 0.86047, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 3s 315ms/step - loss: 3.3306e-04 - accuracy: 1.0000 - val_loss: 0.6104 - val_accuracy: 0.8605
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 2.6536e-04 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 170ms/step - loss: 2.6536e-04 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 0.8605
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 1.9879e-04 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 180ms/step - loss: 1.9879e-04 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.8605
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 1.6248e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 173ms/step - loss: 1.6248e-04 - accuracy: 1.0000 - val_loss: 0.4413 - val_accuracy: 0.8605
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 2.2820e-04 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 179ms/step - loss: 2.2820e-04 - accuracy: 1.0000 - val_loss: 0.4115 - val_accuracy: 0.8605
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 1.3013e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 172ms/step - loss: 1.3013e-04 - accuracy: 1.0000 - val_loss: 0.3952 - val_accuracy: 0.8605
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 1.4562e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 169ms/step - loss: 1.4562e-04 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.8605
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2822e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 171ms/step - loss: 1.2822e-04 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.8605
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2351e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 184ms/step - loss: 1.2351e-04 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8605
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 1.0848e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 169ms/step - loss: 1.0848e-04 - accuracy: 1.0000 - val_loss: 0.3886 - val_accuracy: 0.8605
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 9.5846e-05 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 173ms/step - loss: 9.5846e-05 - accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.8605
# Epoch 15: early stopping

# %%
loss = history1.history['loss']
loss_val = history1.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='loss_val')
plt.title('value of the loss function')
plt.xlabel('epochs')
plt.ylabel('value of the loss function')
plt.legend()
plt.grid()
plt.show()

# %%
train_loss, train_acc = model1.evaluate(train_ds)
print('Train Accuracy:', train_acc*100)
print('\n')

test_loss, test_acc = model1.evaluate(test_ds)
print('Test Accuracy:', test_acc*100)
print('\n')

val_loss, val_acc = model1.evaluate(val_ds)
print('Validation Accuracy:', val_acc*100)
# Out:
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5436 - accuracy: 0.7917
# Train Accuracy: 79.16666865348816
#
#
# 1/1 [==============================] - 0s 264ms/step - loss: 0.6207 - accuracy: 0.7500
# Test Accuracy: 75.0
#
#
# 3/3 [==============================] - 1s 62ms/step - loss: 0.3811 - accuracy: 0.8605
# Validation Accuracy: 86.04651093482971

# %% [markdown]
# ## 결과 확인하기

# %%
for i in test_ds.take(1):
    sample = i
sample = sample[0]
cls = model1(sample)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
