# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/iitp/Facial-Expression-Recognition/modeling
# Out:
# /content/drive/MyDrive/iitp/Facial-Expression-Recognition/modeling

# %%
from tqdm import tqdm
import re
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import random
import keras
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import IPython.display as display

# %%
@tf.function
def landmark_tfrecord_reader(example):
    feature_description = {"image": tf.io.VarLenFeature(dtype=tf.string),
                           "class": tf.io.VarLenFeature(dtype=tf.int64),
                           "landmark_points": tf.io.VarLenFeature(dtype=tf.float32)}

    inputs = {}
    example = tf.io.parse_single_example(example, feature_description)
    image_raw = tf.sparse.to_dense(example["image"])[0]
    inputs['image'] = tf.io.decode_png(image_raw, channels=3)
    image_class = tf.sparse.to_dense(example["class"])
    inputs['image_landmarks'] = tf.sparse.to_dense(example["landmark_points"])
    return inputs, image_class

# %%
def image_scaling(x, y):
    x['image'] = tf.cast(x['image'], tf.float32) / 255.
    return x, y

# %%
filenames = '../data/face_data5.tfrecord'
ds = tf.data.TFRecordDataset(filenames).map(landmark_tfrecord_reader)
ds = ds.map(image_scaling).batch(16)
ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
dataset = tf.data.TFRecordDataset(filenames = ['../data/face_data4.tfrecord'])
raw_example = next(iter(dataset))
parsed = tf.train.Example.FromString(raw_example.numpy())

parsed.features.feature['class']
# Out:
# int64_list {
#   value: 0
# }

# %%
for i in ds.take(1):
    print(i[0]['image'].shape)
    print(i[1].shape)
# Out:
# (16, 224, 224, 3)
# (16, 1)

# %%
ds_size = len(list(ds))
ds_size
# Out:
# 16

# %%
train_size = int(0.7 * ds_size)
val_size = int(0.15 * ds_size)
test_size = int(0.15 * ds_size)

train_ds = ds.take(train_size)
test_ds = ds.skip(train_size)
val_ds = test_ds.skip(val_size)
test_ds = test_ds.take(test_size)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

def callbackFunction(modelName):
  checkpoint = ModelCheckpoint(f"./Checkpoints/{modelName}.h5", monitor = "val_accuracy", save_best_only = True, mode = "auto", verbose = 1)
  # early_stopping = EarlyStopping(monitor = "val_accuracy", patience = 10, verbose = 1)
  # callbacks = [early_stopping, checkpoint]
  callbacks = [checkpoint]
  return callbacks

# %% [markdown]
# # with mobilenetV2

# %% [markdown]
# ### 새롭게 모델 다운

# %%
# # sequential 클래스 이용
# model2 = keras.models.Sequential()

# model2.add(keras.layers.Input(shape=(224,224,3)))
# model2.add(tf.keras.applications.mobilenet_v2.MobileNetV2(
#     input_shape=(224,224,3), alpha=1.0, include_top=False, weights='imagenet'
# ))
# model2.add(keras.layers.Flatten())

# model2.add(keras.layers.Dense(128))
# model2.add(keras.layers.BatchNormalization())
# model2.add(keras.layers.Activation('relu'))
# model2.add(keras.layers.Dropout(0.6))

# model2.add(keras.layers.Dense(64))

# # model2.add(keras.layers.Dense(1, activation='softmax'))
# model2.add(keras.layers.Dense(1, activation='sigmoid'))
# model2.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
#     loss='binary_crossentropy',
#     metrics=['accuracy'])

# %%
moblienet = tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(224,224,3), alpha=1.0, include_top=False, weights='imagenet'
)

# %%
# 함수형 api
input = keras.layers.Input(shape=(224,224,3), name='image')
input2 = keras.layers.Input(shape=(266), name='image_landmarks')
x = moblienet(input)
x = keras.layers.Flatten()(x)

x2 = keras.layers.Dense(128)(input2)
x2 = keras.layers.BatchNormalization()(x2)
x2 = keras.layers.Activation('relu')(x2)
x = keras.layers.concatenate([x, x2])

x = keras.layers.Dense(256)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.3)(x)

x = keras.layers.Dense(128)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.7)(x)

x = keras.layers.Dense(64)(x)
output = keras.layers.Dense(1, activation='sigmoid')(x)
# x_class = keras.layers.Dense(1, activation='sigmoid')(x)
# x_landmark = keras.layers.Dense(266)(x)
# output = keras.layers.concatenate([x_class, x_landmark])

model2 = keras.models.Model(inputs=[input, input2], outputs=output)
model2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=['accuracy'])

# %% [markdown]
# ### 기존 모델로 계속 학습

# %%
model2 = tf.keras.models.load_model('Checkpoints/moblienetV2_4.h5')

# %% [markdown]
# ### 모델 학습

# %%
from keras.utils.vis_utils import plot_model
plot_model(model2, to_file='model.png')

# %%
model2.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_landmarks (InputLayer)   [(None, 266)]        0           []
#
#  image (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  dense_20 (Dense)               (None, 128)          34176       ['image_landmarks[0][0]']
#
#  mobilenetv2_1.00_224 (Function  (None, 7, 7, 1280)  2257984     ['image[0][0]']
#  al)
#
#  batch_normalization_12 (BatchN  (None, 128)         512         ['dense_20[0][0]']
#  ormalization)
#
#  flatten_4 (Flatten)            (None, 62720)        0           ['mobilenetv2_1.00_224[0][0]']
#
#  activation_12 (Activation)     (None, 128)          0           ['batch_normalization_12[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 62848)        0           ['flatten_4[0][0]',
#                                                                   'activation_12[0][0]']
#
#  dense_21 (Dense)               (None, 256)          16089344    ['concatenate_4[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 256)         1024        ['dense_21[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 256)          0           ['batch_normalization_13[0][0]']
#
#  dropout_8 (Dropout)            (None, 256)          0           ['activation_13[0][0]']
#
#  dense_22 (Dense)               (None, 128)          32896       ['dropout_8[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 128)         512         ['dense_22[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 128)          0           ['batch_normalization_14[0][0]']
#
#  dropout_9 (Dropout)            (None, 128)          0           ['activation_14[0][0]']
#
#  dense_23 (Dense)               (None, 64)           8256        ['dropout_9[0][0]']
#
#  dense_24 (Dense)               (None, 1)            65          ['dense_23[0][0]']
#
# ==================================================================================================
# Total params: 18,424,769
# Trainable params: 18,389,633
# Non-trainable params: 35,136
# __________________________________________________________________________________________________

# %%
history2 = model2.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=callbackFunction('moblienetV2_landmark_2'), batch_size=16)
# Out:
# Epoch 1/50
#      11/Unknown - 11s 138ms/step - loss: 0.1600 - accuracy: 0.9318
# Epoch 1: val_accuracy improved from -inf to 0.56818, saving model to ./Checkpoints/moblienetV2_landmark_2.h5
# 11/11 [==============================] - 14s 506ms/step - loss: 0.1600 - accuracy: 0.9318 - val_loss: 1.0582 - val_accuracy: 0.5682
# Epoch 2/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 2: val_accuracy improved from 0.56818 to 0.65909, saving model to ./Checkpoints/moblienetV2_landmark_2.h5
# 11/11 [==============================] - 3s 281ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.6591
# Epoch 3/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 1.0000
# Epoch 3: val_accuracy improved from 0.65909 to 1.00000, saving model to ./Checkpoints/moblienetV2_landmark_2.h5
# 11/11 [==============================] - 3s 275ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 4/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 4: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 5/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 5: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 159ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 6/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 161ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 7/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 8/50
# 11/11 [==============================] - ETA: 0s - loss: 9.9475e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 149ms/step - loss: 9.9475e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 9/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 158ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 10/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 140ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 11/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 9.3267e-04 - val_accuracy: 1.0000
# Epoch 12/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 164ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.9549e-04 - val_accuracy: 1.0000
# Epoch 13/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 171ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 7.3550e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 159ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.3149e-04 - val_accuracy: 1.0000
# Epoch 15/50
# 11/11 [==============================] - ETA: 0s - loss: 6.7488e-04 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 143ms/step - loss: 6.7488e-04 - accuracy: 1.0000 - val_loss: 4.6813e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 11/11 [==============================] - ETA: 0s - loss: 6.4490e-04 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 142ms/step - loss: 6.4490e-04 - accuracy: 1.0000 - val_loss: 3.1056e-04 - val_accuracy: 1.0000
# Epoch 17/50
# 11/11 [==============================] - ETA: 0s - loss: 8.1999e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 143ms/step - loss: 8.1999e-04 - accuracy: 1.0000 - val_loss: 2.4179e-04 - val_accuracy: 1.0000
# Epoch 18/50
# 11/11 [==============================] - ETA: 0s - loss: 3.2238e-04 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 141ms/step - loss: 3.2238e-04 - accuracy: 1.0000 - val_loss: 1.9973e-04 - val_accuracy: 1.0000
# Epoch 19/50
# 11/11 [==============================] - ETA: 0s - loss: 4.2937e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 141ms/step - loss: 4.2937e-04 - accuracy: 1.0000 - val_loss: 1.4495e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 11/11 [==============================] - ETA: 0s - loss: 8.5942e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 153ms/step - loss: 8.5942e-04 - accuracy: 1.0000 - val_loss: 9.6821e-05 - val_accuracy: 1.0000
# Epoch 21/50
# 11/11 [==============================] - ETA: 0s - loss: 5.9817e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 152ms/step - loss: 5.9817e-04 - accuracy: 1.0000 - val_loss: 6.5554e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 11/11 [==============================] - ETA: 0s - loss: 5.2894e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 145ms/step - loss: 5.2894e-04 - accuracy: 1.0000 - val_loss: 5.1754e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 11/11 [==============================] - ETA: 0s - loss: 5.9634e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 141ms/step - loss: 5.9634e-04 - accuracy: 1.0000 - val_loss: 4.2707e-05 - val_accuracy: 1.0000
# Epoch 24/50
# 11/11 [==============================] - ETA: 0s - loss: 6.7764e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 142ms/step - loss: 6.7764e-04 - accuracy: 1.0000 - val_loss: 3.7227e-05 - val_accuracy: 1.0000
# Epoch 25/50
# 11/11 [==============================] - ETA: 0s - loss: 2.0562e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 142ms/step - loss: 2.0562e-04 - accuracy: 1.0000 - val_loss: 3.3444e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 11/11 [==============================] - ETA: 0s - loss: 3.8583e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 151ms/step - loss: 3.8583e-04 - accuracy: 1.0000 - val_loss: 2.6095e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 11/11 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.5633e-05 - val_accuracy: 1.0000
# Epoch 28/50
# 11/11 [==============================] - ETA: 0s - loss: 4.2476e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 152ms/step - loss: 4.2476e-04 - accuracy: 1.0000 - val_loss: 1.0156e-05 - val_accuracy: 1.0000
# Epoch 29/50
# 11/11 [==============================] - ETA: 0s - loss: 2.6372e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 153ms/step - loss: 2.6372e-04 - accuracy: 1.0000 - val_loss: 8.6792e-06 - val_accuracy: 1.0000
# Epoch 30/50
# 11/11 [==============================] - ETA: 0s - loss: 4.1305e-04 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 151ms/step - loss: 4.1305e-04 - accuracy: 1.0000 - val_loss: 8.4027e-06 - val_accuracy: 1.0000
# Epoch 31/50
# 11/11 [==============================] - ETA: 0s - loss: 1.3672e-04 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 146ms/step - loss: 1.3672e-04 - accuracy: 1.0000 - val_loss: 8.2304e-06 - val_accuracy: 1.0000
# Epoch 32/50
# 11/11 [==============================] - ETA: 0s - loss: 4.3093e-04 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 141ms/step - loss: 4.3093e-04 - accuracy: 1.0000 - val_loss: 6.7067e-06 - val_accuracy: 1.0000
# Epoch 33/50
# 11/11 [==============================] - ETA: 0s - loss: 2.0573e-04 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 152ms/step - loss: 2.0573e-04 - accuracy: 1.0000 - val_loss: 5.5368e-06 - val_accuracy: 1.0000
# Epoch 34/50
# 11/11 [==============================] - ETA: 0s - loss: 3.0137e-04 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 147ms/step - loss: 3.0137e-04 - accuracy: 1.0000 - val_loss: 4.6235e-06 - val_accuracy: 1.0000
# Epoch 35/50
# 11/11 [==============================] - ETA: 0s - loss: 3.4328e-04 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 155ms/step - loss: 3.4328e-04 - accuracy: 1.0000 - val_loss: 4.1393e-06 - val_accuracy: 1.0000
# Epoch 36/50
# 11/11 [==============================] - ETA: 0s - loss: 1.4019e-04 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 152ms/step - loss: 1.4019e-04 - accuracy: 1.0000 - val_loss: 4.0958e-06 - val_accuracy: 1.0000
# Epoch 37/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2539e-04 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 183ms/step - loss: 1.2539e-04 - accuracy: 1.0000 - val_loss: 4.1448e-06 - val_accuracy: 1.0000
# Epoch 38/50
# 11/11 [==============================] - ETA: 0s - loss: 7.9629e-05 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 167ms/step - loss: 7.9629e-05 - accuracy: 1.0000 - val_loss: 3.9467e-06 - val_accuracy: 1.0000
# Epoch 39/50
# 11/11 [==============================] - ETA: 0s - loss: 1.8889e-04 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 197ms/step - loss: 1.8889e-04 - accuracy: 1.0000 - val_loss: 3.7131e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 11/11 [==============================] - ETA: 0s - loss: 2.1687e-04 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 193ms/step - loss: 2.1687e-04 - accuracy: 1.0000 - val_loss: 3.5212e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 11/11 [==============================] - ETA: 0s - loss: 1.7936e-04 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 216ms/step - loss: 1.7936e-04 - accuracy: 1.0000 - val_loss: 3.2953e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2950e-04 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 184ms/step - loss: 1.2950e-04 - accuracy: 1.0000 - val_loss: 3.0915e-06 - val_accuracy: 1.0000
# Epoch 43/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2001e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 177ms/step - loss: 1.2001e-04 - accuracy: 1.0000 - val_loss: 2.8510e-06 - val_accuracy: 1.0000
# Epoch 44/50
# 11/11 [==============================] - ETA: 0s - loss: 2.4149e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 154ms/step - loss: 2.4149e-04 - accuracy: 1.0000 - val_loss: 2.5350e-06 - val_accuracy: 1.0000
# Epoch 45/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0314e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 153ms/step - loss: 1.0314e-04 - accuracy: 1.0000 - val_loss: 2.2865e-06 - val_accuracy: 1.0000
# Epoch 46/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1858e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 145ms/step - loss: 1.1858e-04 - accuracy: 1.0000 - val_loss: 2.1465e-06 - val_accuracy: 1.0000
# Epoch 47/50
# 11/11 [==============================] - ETA: 0s - loss: 5.9005e-05 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 147ms/step - loss: 5.9005e-05 - accuracy: 1.0000 - val_loss: 2.0194e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 11/11 [==============================] - ETA: 0s - loss: 2.9250e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 140ms/step - loss: 2.9250e-04 - accuracy: 1.0000 - val_loss: 1.9075e-06 - val_accuracy: 1.0000
# Epoch 49/50
# 11/11 [==============================] - ETA: 0s - loss: 1.2071e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 144ms/step - loss: 1.2071e-04 - accuracy: 1.0000 - val_loss: 1.6400e-06 - val_accuracy: 1.0000
# Epoch 50/50
# 11/11 [==============================] - ETA: 0s - loss: 5.9912e-05 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 1.00000
# 11/11 [==============================] - 2s 154ms/step - loss: 5.9912e-05 - accuracy: 1.0000 - val_loss: 1.4527e-06 - val_accuracy: 1.0000

# %%
loss = history2.history['loss']
loss_val = history2.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='loss_val')
plt.title('value of the loss function')
plt.xlabel('epochs')
plt.ylabel('value of the loss function')
plt.legend()
plt.grid()
plt.show()

# %%
train_loss, train_acc = model2.evaluate(train_ds)
print('Train Accuracy:', train_acc*100)
print('\n')

test_loss, test_acc = model2.evaluate(test_ds)
print('Test Accuracy:', test_acc*100)
print('\n')

val_loss, val_acc = model2.evaluate(val_ds)
print('Validation Accuracy:', val_acc*100)
# Out:
# 11/11 [==============================] - 0s 30ms/step - loss: 1.4017e-06 - accuracy: 1.0000
# Train Accuracy: 100.0
#
#
# 2/2 [==============================] - 0s 64ms/step - loss: 1.2909e-06 - accuracy: 1.0000
# Test Accuracy: 100.0
#
#
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4527e-06 - accuracy: 1.0000
# Validation Accuracy: 100.0

# %% [markdown]
# ### 결과 확인하기

# %%
filenames = '../data/face_data2.tfrecord'
new_test = tf.data.TFRecordDataset(filenames).map(landmark_tfrecord_reader)
new_test = new_test.map(image_scaling).batch(16)
new_test = new_test.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
for i in new_test.take(1):
    sample = i
sample_input ={}
sample_input['image_landmarks'] = sample[0]['image_landmarks']
sample_input['image'] = sample[0]['image']

cls = model2(sample_input)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')

# %%
for i in test_ds.take(1):
    sample = i
sample_input ={}
sample_input['image_landmarks'] = sample[0]['image_landmarks']
sample_input['image'] = sample[0]['image']

cls = model2(sample_input)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample_input['image'][i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
raw_example = next(iter(test_ds))
image = raw_example[0]['image'][15].numpy()
cls = model2(raw_example[0])
labels = cls[15].numpy()
ax = plt.subplot(3, 3, i + 1)
ax.set_title(labels) 
plt.imshow(image)
plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# # moblienetV2 structure

# %%
model1 = keras.models.Sequential()

model1.add(keras.layers.Input(shape=(256,256,3)))
model1.add(tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(256,256,3), alpha=1.0, include_top=False
))
model1.add(keras.layers.Flatten())

model1.add(keras.layers.Dense(128))
model1.add(keras.layers.BatchNormalization())
model1.add(keras.layers.Activation('relu'))
model1.add(keras.layers.Dropout(0.25))

model1.add(keras.layers.Dense(64))

model1.add(keras.layers.Dense(1, activation='sigmoid'))
model1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 8, 8, 1280)       2257984
#  ional)
#
#  flatten_1 (Flatten)         (None, 81920)             0
#
#  dense_3 (Dense)             (None, 128)               10485888
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12,752,705
# Trainable params: 12,718,337
# Non-trainable params: 34,368
# _________________________________________________________________

# %%
history1 = model1.fit(train_ds, validation_data=val_ds, epochs=50, callbacks=callbackFunction('moblienetV2_noweight'), batch_size=32)
# Out:
# Epoch 1/50
#       9/Unknown - 23s 134ms/step - loss: 0.0688 - accuracy: 0.9792
# Epoch 1: val_accuracy improved from -inf to 0.69767, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 28s 757ms/step - loss: 0.0688 - accuracy: 0.9792 - val_loss: 7.0072 - val_accuracy: 0.6977
# Epoch 2/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 2: val_accuracy did not improve from 0.69767
# 9/9 [==============================] - 2s 166ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.0622 - val_accuracy: 0.6977
# Epoch 3/50
# 9/9 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 3: val_accuracy improved from 0.69767 to 0.72093, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 4s 474ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3490 - val_accuracy: 0.7209
# Epoch 4/50
# 9/9 [==============================] - ETA: 0s - loss: 5.4341e-04 - accuracy: 1.0000
# Epoch 4: val_accuracy improved from 0.72093 to 0.83721, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 3s 306ms/step - loss: 5.4341e-04 - accuracy: 1.0000 - val_loss: 0.8140 - val_accuracy: 0.8372
# Epoch 5/50
# 9/9 [==============================] - ETA: 0s - loss: 3.3306e-04 - accuracy: 1.0000
# Epoch 5: val_accuracy improved from 0.83721 to 0.86047, saving model to ./Checkpoints/moblienetV2_noweight.h5
# 9/9 [==============================] - 3s 315ms/step - loss: 3.3306e-04 - accuracy: 1.0000 - val_loss: 0.6104 - val_accuracy: 0.8605
# Epoch 6/50
# 9/9 [==============================] - ETA: 0s - loss: 2.6536e-04 - accuracy: 1.0000
# Epoch 6: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 170ms/step - loss: 2.6536e-04 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 0.8605
# Epoch 7/50
# 9/9 [==============================] - ETA: 0s - loss: 1.9879e-04 - accuracy: 1.0000
# Epoch 7: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 180ms/step - loss: 1.9879e-04 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.8605
# Epoch 8/50
# 9/9 [==============================] - ETA: 0s - loss: 1.6248e-04 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 173ms/step - loss: 1.6248e-04 - accuracy: 1.0000 - val_loss: 0.4413 - val_accuracy: 0.8605
# Epoch 9/50
# 9/9 [==============================] - ETA: 0s - loss: 2.2820e-04 - accuracy: 1.0000
# Epoch 9: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 179ms/step - loss: 2.2820e-04 - accuracy: 1.0000 - val_loss: 0.4115 - val_accuracy: 0.8605
# Epoch 10/50
# 9/9 [==============================] - ETA: 0s - loss: 1.3013e-04 - accuracy: 1.0000
# Epoch 10: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 172ms/step - loss: 1.3013e-04 - accuracy: 1.0000 - val_loss: 0.3952 - val_accuracy: 0.8605
# Epoch 11/50
# 9/9 [==============================] - ETA: 0s - loss: 1.4562e-04 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 169ms/step - loss: 1.4562e-04 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.8605
# Epoch 12/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2822e-04 - accuracy: 1.0000
# Epoch 12: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 171ms/step - loss: 1.2822e-04 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.8605
# Epoch 13/50
# 9/9 [==============================] - ETA: 0s - loss: 1.2351e-04 - accuracy: 1.0000
# Epoch 13: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 184ms/step - loss: 1.2351e-04 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8605
# Epoch 14/50
# 9/9 [==============================] - ETA: 0s - loss: 1.0848e-04 - accuracy: 1.0000
# Epoch 14: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 169ms/step - loss: 1.0848e-04 - accuracy: 1.0000 - val_loss: 0.3886 - val_accuracy: 0.8605
# Epoch 15/50
# 9/9 [==============================] - ETA: 0s - loss: 9.5846e-05 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.86047
# 9/9 [==============================] - 2s 173ms/step - loss: 9.5846e-05 - accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.8605
# Epoch 15: early stopping

# %%
loss = history1.history['loss']
loss_val = history1.history['val_loss']
epochs = range(1, len(loss)+1)
plt.plot(epochs, loss, 'bo', label='loss_train')
plt.plot(epochs, loss_val, 'b', label='loss_val')
plt.title('value of the loss function')
plt.xlabel('epochs')
plt.ylabel('value of the loss function')
plt.legend()
plt.grid()
plt.show()

# %%
train_loss, train_acc = model1.evaluate(train_ds)
print('Train Accuracy:', train_acc*100)
print('\n')

test_loss, test_acc = model1.evaluate(test_ds)
print('Test Accuracy:', test_acc*100)
print('\n')

val_loss, val_acc = model1.evaluate(val_ds)
print('Validation Accuracy:', val_acc*100)
# Out:
# 9/9 [==============================] - 0s 35ms/step - loss: 0.5436 - accuracy: 0.7917
# Train Accuracy: 79.16666865348816
#
#
# 1/1 [==============================] - 0s 264ms/step - loss: 0.6207 - accuracy: 0.7500
# Test Accuracy: 75.0
#
#
# 3/3 [==============================] - 1s 62ms/step - loss: 0.3811 - accuracy: 0.8605
# Validation Accuracy: 86.04651093482971

# %% [markdown]
# ## 결과 확인하기

# %%
for i in test_ds.take(1):
    sample = i
sample = sample[0]
cls = model1(sample)
plt.figure(figsize=(16, 16))
for i in range(9):
    image = sample[i].numpy()
    labels = cls[i].numpy()
    ax = plt.subplot(3, 3, i + 1)
    ax.set_title(labels) 
    plt.imshow(image)
    plt.axis('off')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
